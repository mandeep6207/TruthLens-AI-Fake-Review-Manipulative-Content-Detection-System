# %% [markdown]
# # TruthLens AI Analysis Notebook
#
# This notebook documents the end-to-end workflow for the TruthLens AI fake review detection system, including dataset inspection, preprocessing, visual analysis, and model evaluation.

# %%
from pathlib import Path
import pandas as pd

data_path = Path('../data/cleaned_reviews.csv')
reviews = pd.read_csv(data_path)
reviews.head()

# %% [markdown]
# ## Dataset Overview
#
# The cleaned dataset contains the original review text, the normalized text, and engineered behavioral features used for analysis and modeling.

# %%
reviews.info()

# %%
from IPython.display import Image, display

for image_name in [
    'review_distribution.png',
    'fake_vs_real_pie.png',
    'wordcloud_real.png',
    'wordcloud_fake.png',
    'sentiment_distribution.png',
    'review_length_analysis.png',
    'correlation_heatmap.png',
    'confusion_matrix.png',
    'feature_importance.png',
]:
    display(Image(filename=f'../visuals/{image_name}'))

# %% [markdown]
# ## Visual Exploration
#
# The following figures are saved in the `visuals/` directory and summarize the strongest patterns in the data.

# %%
sample_columns = [
    'review_text',
    'cleaned_review_text',
    'review_length',
    'sentiment_score',
    'suspicious_word_count',
]
reviews[sample_columns].head()

# %% [markdown]
# ## Final Insights
#
# Fake reviews in this project are highly repetitive, promotional, and structurally different from real reviews, which makes them separable with a combined TF-IDF plus behavioral feature pipeline.
